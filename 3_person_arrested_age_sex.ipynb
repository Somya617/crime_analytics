# %%
import pandas as pd

# %%
prsn_arr_IPC_12 = pd.read_csv(r"D:\Data Science\Intern\Code\AggregrateData\07_01_Persons_arrested_by_sex_and_age_group_IPC_2012.csv")
prsn_arr_IPC_13 = pd.read_csv(r"D:\Data Science\Intern\Code\AggregrateData\07_01_Persons_arrested_by_sex_and_age_group_IPC_2013.csv")
prsn_arr_IPC_14 = pd.read_csv(r"D:\Data Science\Intern\Code\AggregrateData\07_01_Persons_arrested_by_sex_and_age_group_IPC_2014.csv")
prsn_arr_SLL_12 = pd.read_csv(r"D:\Data Science\Intern\Code\AggregrateData\07_02_Persons_arrested_by_sex_and_age_group_SLL_2012.csv")
prsn_arr_SLL_13 = pd.read_csv(r"D:\Data Science\Intern\Code\AggregrateData\07_02_Persons_arrested_by_sex_and_age_group_SLL_2013.csv")
prsn_arr_SLL_14 = pd.read_csv(r"D:\Data Science\Intern\Code\AggregrateData\07_02_Persons_arrested_by_sex_and_age_group_SLL_2014.csv")

# %%
prsn_arr_IPC_12.head()
# Out:
#             STATE/UT                CRIME HEAD  Male Below 18 Years  \
# 0     ANDHRA PRADESH  MURDER (SECTION 302 IPC)                   65
# 1  ARUNACHAL PRADESH  MURDER (SECTION 302 IPC)                    0
# 2              ASSAM  MURDER (SECTION 302 IPC)                   38
# 3              BIHAR  MURDER (SECTION 302 IPC)                   60
# 4       CHHATTISGARH  MURDER (SECTION 302 IPC)                   64
#
#    Female Below 18 Years  Male Between 18-30 Years  \
# 0                      3                      2054
# 1                      0                        53
# 2                      0                       584
# 3                      5                      2983
# 4                      5                       560
#
#    Female Between 18-30 Years  Male Between 30-45 Years  \
# 0                         187                      1866
# 1                           0                        52
# 2                          23                       738
# ...

# %%
prsn_arr_IPC_13.head()
# Out:
#             STATE/UT CRIME HEAD  Male Below 18 Years  Female Below 18 Years  \
# 0     Andhra Pradesh      Arson                    4                      0
# 1  Arunachal Pradesh      Arson                    0                      0
# 2              Assam      Arson                    9                      0
# 3              Bihar      Arson                    1                      0
# 4       Chhattisgarh      Arson                    2                      2
#
#    Male Between 18-30 Years  Female Between 18-30 Years  \
# 0                       298                          11
# 1                         7                           0
# 2                       291                           0
# 3                       687                           7
# 4                       127                           4
#
#    Male Between 30-45 Years  Female Between 30-45 Years  \
# 0                       359                          11
# ...

# %%
prsn_arr_IPC_14.head()
# Out:
#        States/UTs                                         Crime Head  Year  \
# 0  Andhra Pradesh                       1 - Murder (Section 302 IPC)  2014
# 1  Andhra Pradesh     2 - Attempt to commit Murder (Section 307 IPC)  2014
# 2  Andhra Pradesh  3 - Culpable Homicide not amounting to Murder ...  2014
# 3  Andhra Pradesh  4 - Attempt to commit Culpable Homicide (Secti...  2014
# 4  Andhra Pradesh                         5 - Rape (Section 376 IPC)  2014
#
#    18 and above and below 30 years_Male  \
# 0                                   754
# 1                                  1175
# 2                                    16
# 3                                     0
# 4                                   708
#
#    18 and above and below 30 years_Female  \
# 0                                      59
# 1                                      38
# 2                                       2
# 3                                       0
# 4                                       7
#
# ...

# %%
column_mapping = {
    '18 and above and below 30 years_Male': 'Male Between 18-30 Years',
    '18 and above and below 30 years_Female': 'Female Between 18-30 Years',
    '18 and above and below 30 years_Total': 'Total Between 18-30 Years',
    '30 and above and below 45 years_Male': 'Male Between 30-45 Years',
    '30 and above and below 45 years_Female': 'Female Between 30-45 Years',
    '30 and above and below 45 years_Total': 'Total Between 30-45 Years',
    '45 and above and below 60 years_Male': 'Male Between 45-60 Years',
    '45 and above and below 60 years_Female': 'Female Between 45-60 Years',
    '45 and above and below 60 years_Total': 'Total Between 45-60 Years',
    '60 years and above_Male': 'Male Above 60 Years',
    '60 years and above_Female': 'Female Above 60 Years',
    '60 years and above_Total': 'Total Above 60 Years',
    'Total Male': 'Male Total',
    'Total Female': 'Female Total',
    'Total Persons Arrested by age and Sex': 'Grand Total'
}
prsn_arr_IPC_14.rename(columns=column_mapping, inplace = True)
prsn_arr_SLL_14.rename(columns=column_mapping, inplace = True)

# %%
prsn_arr_IPC_14.head()
# Out:
#          STATE/UT                                         CRIME HEAD  Year  \
# 0  Andhra Pradesh                       1 - Murder (Section 302 IPC)  2014
# 1  Andhra Pradesh     2 - Attempt to commit Murder (Section 307 IPC)  2014
# 2  Andhra Pradesh  3 - Culpable Homicide not amounting to Murder ...  2014
# 3  Andhra Pradesh  4 - Attempt to commit Culpable Homicide (Secti...  2014
# 4  Andhra Pradesh                         5 - Rape (Section 376 IPC)  2014
#
#    Male Between 18-30 Years  Female Between 18-30 Years  \
# 0                       754                          59
# 1                      1175                          38
# 2                        16                           2
# 3                         0                           0
# 4                       708                           7
#
#    Total Between 18-30 Years  Male Between 30-45 Years  \
# 0                        813                       772
# 1                       1213                       920
# ...

# %%
prsn_arr_SLL_14.head()
# Out:
#          STATE/UT                                         CRIME HEAD  Year  \
# 0  Andhra Pradesh                                 1 - Arms Act, 1959  2014
# 1  Andhra Pradesh  2 - Narcotic Drugs & Psychotropic Substances A...  2014
# 2  Andhra Pradesh                             3 - Gambling Act, 1867  2014
# 3  Andhra Pradesh                               4 - Excise Act, 1944  2014
# 4  Andhra Pradesh                                5 - Prohibition Act  2014
#
#    Male Between 18-30 Years  Female Between 18-30 Years  \
# 0                        73                           3
# 1                       303                          14
# 2                     12473                           0
# 3                      2142                          38
# 4                       300                           2
#
#    Total Between 18-30 Years  Male Between 30-45 Years  \
# 0                         76                       155
# 1                        317                       310
# ...

# %%
prsn_arr_IPC_12["Year"] = 2012
prsn_arr_IPC_13["Year"] = 2013
prsn_arr_SLL_12["Year"] = 2012
prsn_arr_SLL_13["Year"] = 2013

# %%
prsn_arr_IPC_14.rename(columns={"Crime Head":"CRIME HEAD"}, inplace = True)
prsn_arr_SLL_14.rename(columns={"Crime Head":"CRIME HEAD"}, inplace = True)

# %%
prsn_arr_IPC_14["Male Below 18 Years"] = 0
prsn_arr_IPC_14["Female Below 18 Years"] = 0
prsn_arr_SLL_14["Male Below 18 Years"] = 0
prsn_arr_SLL_14["Female Below 18 Years"] = 0

# %%
prsn_arr_SLL_14.columns
# Out:
# Index(['States/UTs', 'CRIME HEAD', 'Year', 'Male Between 18-30 Years',
#        'Female Between 18-30 Years', 'Total Between 18-30 Years',
#        'Male Between 30-45 Years', 'Female Between 30-45 Years',
#        'Total Between 30-45 Years', 'Male Between 45-60 Years',
#        'Female Between 45-60 Years', 'Total Between 45-60 Years',
#        'Male Above 60 Years', 'Female Above 60 Years', 'Total Above 60 Years',
#        'Male Total', 'Female Total', 'Grand Total', 'Male Below 18 Years',
#        'Female Below 18 Years'],
#       dtype='object')

# %%
prsn_arr_SLL_13.columns
# Out:
# Index(['STATE/UT', 'CRIME HEAD', 'Male Below 18 Years',
#        'Female Below 18 Years', 'Male Between 18-30 Years',
#        'Female Between 18-30 Years', 'Male Between 30-45 Years',
#        'Female Between 30-45 Years', 'Male Between 45-60 Years',
#        'Female Between 45-60 Years', 'Male Above 60 Years',
#        'Female Above 60 Years', 'Male Total', 'Female Total', 'Grand Total',
#        'Year'],
#       dtype='object')

# %%
prsn_arr_SLL_13["Legal Framework"] = "SLL"
prsn_arr_SLL_12["Legal Framework"] = "SLL"
prsn_arr_SLL_14["Legal Framework"] = "SLL"
prsn_arr_IPC_12["Legal Framework"] = "IPC"
prsn_arr_IPC_13["Legal Framework"] = "IPC"
prsn_arr_IPC_14["Legal Framework"] = "IPC"

# %%
prsn_arr_SLL_13.head()
# Out:
#             STATE/UT                           CRIME HEAD  \
# 0     Andhra Pradesh  Antiquity & Art Treasures Act, 1972
# 1  Arunachal Pradesh  Antiquity & Art Treasures Act, 1972
# 2              Assam  Antiquity & Art Treasures Act, 1972
# 3              Bihar  Antiquity & Art Treasures Act, 1972
# 4       Chhattisgarh  Antiquity & Art Treasures Act, 1972
#
#    Male Below 18 Years  Female Below 18 Years  Male Between 18-30 Years  \
# 0                    0                      0                         7
# 1                    0                      0                         0
# 2                    0                      0                         0
# 3                    0                      0                         4
# 4                    0                      0                         0
#
#    Female Between 18-30 Years  Male Between 30-45 Years  \
# 0                           0                        16
# 1                           0                         0
# ...

# %%
prsn_arr_SLL_14.head()
# Out:
#        States/UTs                                         CRIME HEAD  Year  \
# 0  Andhra Pradesh                                 1 - Arms Act, 1959  2014
# 1  Andhra Pradesh  2 - Narcotic Drugs & Psychotropic Substances A...  2014
# 2  Andhra Pradesh                             3 - Gambling Act, 1867  2014
# 3  Andhra Pradesh                               4 - Excise Act, 1944  2014
# 4  Andhra Pradesh                                5 - Prohibition Act  2014
#
#    Male Between 18-30 Years  Female Between 18-30 Years  \
# 0                        73                           3
# 1                       303                          14
# 2                     12473                           0
# 3                      2142                          38
# 4                       300                           2
#
#    Total Between 18-30 Years  Male Between 30-45 Years  \
# 0                         76                       155
# 1                        317                       310
# ...

# %%
prsn_arr_IPC_14.rename(columns={"States/UTs":"STATE/UT"}, inplace = True)
prsn_arr_SLL_14.rename(columns={"States/UTs":"STATE/UT"}, inplace = True)

# %%
prsn_arr_sex_age_final = pd.concat([prsn_arr_IPC_12, prsn_arr_IPC_13, prsn_arr_IPC_14, prsn_arr_SLL_12, prsn_arr_SLL_13, prsn_arr_SLL_14], ignore_index=True)

# %%
prsn_arr_sex_age_final.head()
# Out:
#             STATE/UT                CRIME HEAD  Male Below 18 Years  \
# 0     ANDHRA PRADESH  MURDER (SECTION 302 IPC)                   65
# 1  ARUNACHAL PRADESH  MURDER (SECTION 302 IPC)                    0
# 2              ASSAM  MURDER (SECTION 302 IPC)                   38
# 3              BIHAR  MURDER (SECTION 302 IPC)                   60
# 4       CHHATTISGARH  MURDER (SECTION 302 IPC)                   64
#
#    Female Below 18 Years  Male Between 18-30 Years  \
# 0                      3                      2054
# 1                      0                        53
# 2                      0                       584
# 3                      5                      2983
# 4                      5                       560
#
#    Female Between 18-30 Years  Male Between 30-45 Years  \
# 0                         187                      1866
# 1                           0                        52
# 2                          23                       738
# ...

# %%
prsn_arr_sex_age_final.drop(columns=["Total Between 18-30 Years", "Total Between 30-45 Years", "Total Between 45-60 Years", "Total Above 60 Years"], inplace = True)

# %%
prsn_arr_sex_age_final.head()
# Out:
#             STATE/UT                CRIME HEAD  Male Below 18 Years  \
# 0     ANDHRA PRADESH  MURDER (SECTION 302 IPC)                   65
# 1  ARUNACHAL PRADESH  MURDER (SECTION 302 IPC)                    0
# 2              ASSAM  MURDER (SECTION 302 IPC)                   38
# 3              BIHAR  MURDER (SECTION 302 IPC)                   60
# 4       CHHATTISGARH  MURDER (SECTION 302 IPC)                   64
#
#    Female Below 18 Years  Male Between 18-30 Years  \
# 0                      3                      2054
# 1                      0                        53
# 2                      0                       584
# 3                      5                      2983
# 4                      5                       560
#
#    Female Between 18-30 Years  Male Between 30-45 Years  \
# 0                         187                      1866
# 1                           0                        52
# 2                          23                       738
# ...

# %%
prsn_arr_sex_age_final.isnull().sum()
# Out:
# STATE/UT                      0
# CRIME HEAD                    0
# Male Below 18 Years           0
# Female Below 18 Years         0
# Male Between 18-30 Years      0
# Female Between 18-30 Years    0
# Male Between 30-45 Years      0
# Female Between 30-45 Years    0
# Male Between 45-60 Years      0
# Female Between 45-60 Years    0
# Male Above 60 Years           0
# Female Above 60 Years         0
# Male Total                    0
# Female Total                  0
# Grand Total                   0
# Year                          0
# Legal Framework               0
# dtype: int64
